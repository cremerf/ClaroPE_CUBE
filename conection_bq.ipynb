# %%
from packages.tools import ConnectionBigQuery
import pandas as pd
import numpy as np

# %%
client = ConnectionBigQuery(path_credentials="C:/Users/Federico.Cremer/OneDrive - Havas/Desktop/Science/Claro Peru/credentials.json",project_id="claro-peru-trasabilidad")

client.connect()

query_job = client.simple_query(dataset="Facebook", table="FBADS_AGE_GENDER_20220831",select="*")

#response = query_job.result()

query_job
# Out:
#             account_id                         account_name  \
# 0     3208640299265190  PE_Havas_ClaroPeru_3208640299265190
# 1     3208640299265190  PE_Havas_ClaroPeru_3208640299265190
# 2     3208640299265190  PE_Havas_ClaroPeru_3208640299265190
# 3     3208640299265190  PE_Havas_ClaroPeru_3208640299265190
# 4     3208640299265190  PE_Havas_ClaroPeru_3208640299265190
# ...                ...                                  ...
# 3491  3208640299265190  PE_Havas_ClaroPeru_3208640299265190
# 3492  3208640299265190  PE_Havas_ClaroPeru_3208640299265190
# 3493  3208640299265190  PE_Havas_ClaroPeru_3208640299265190
# 3494  3208640299265190  PE_Havas_ClaroPeru_3208640299265190
# 3495  3208640299265190  PE_Havas_ClaroPeru_3208640299265190
#
#                   ad_id                                            ad_name  \
# 0     23847924407820009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_CTL_N...
# 1     23847924407820009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_CTL_N...
# 2     23847924407820009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_CTL_N...
# 3     23847924407820009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_CTL_N...
# 4     23847924407820009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_CTL_N...
# ...                 ...                                                ...
# 3491  23851258502440009  AON IMAGEN_PPA_NATAG_VIDEO_B2S VIDEOLLAMADA_FA...
# 3492  23851258502440009  AON IMAGEN_PPA_NATAG_VIDEO_B2S VIDEOLLAMADA_FA...
# 3493  23851258502440009  AON IMAGEN_PPA_NATAG_VIDEO_B2S VIDEOLLAMADA_FA...
# 3494  23851258502440009  AON IMAGEN_PPA_NATAG_VIDEO_B2S VIDEOLLAMADA_FA...
# 3495  23851258502440009  AON IMAGEN_PPA_NATAG_VIDEO_B2S VIDEOLLAMADA_FA...
#
#             campaign_id                                      campaign_name  \
# 0     23847838870600009  CLARO_CLAT_DINAMICOS_APPLE_ CONV_CON_FBIGME_23...
# 1     23847838870600009  CLARO_CLAT_DINAMICOS_APPLE_ CONV_CON_FBIGME_23...
# 2     23847838870600009  CLARO_CLAT_DINAMICOS_APPLE_ CONV_CON_FBIGME_23...
# 3     23847838870600009  CLARO_CLAT_DINAMICOS_APPLE_ CONV_CON_FBIGME_23...
# 4     23847838870600009  CLARO_CLAT_DINAMICOS_APPLE_ CONV_CON_FBIGME_23...
# ...                 ...                                                ...
# 3491  23851010411750009  CLARO_CLAI_AON IMAGEN_EQU_CONS_RCH_FBME_01AGO2...
# 3492  23851010411750009  CLARO_CLAI_AON IMAGEN_EQU_CONS_RCH_FBME_01AGO2...
# 3493  23851010411750009  CLARO_CLAI_AON IMAGEN_EQU_CONS_RCH_FBME_01AGO2...
# 3494  23851010411750009  CLARO_CLAI_AON IMAGEN_EQU_CONS_RCH_FBME_01AGO2...
# 3495  23851010411750009  CLARO_CLAI_AON IMAGEN_EQU_CONS_RCH_FBME_01AGO2...
#
#             ad_group_id                                      ad_group_name  \
# 0     23847924407750009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_ABI_C...
# 1     23847924407750009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_ABI_C...
# 2     23847924407750009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_ABI_C...
# 3     23847924407750009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_ABI_C...
# 4     23847924407750009  CLARO POSTPAGO BETA CATALOGO PORTA A0003_ABI_C...
# ...                 ...                                                ...
# 3491  23851258502450009  AON IMAGEN_ABI_CPM_NA_BOLSA HOGAR - FACEBOOK_3...
# 3492  23851258502450009  AON IMAGEN_ABI_CPM_NA_BOLSA HOGAR - FACEBOOK_3...
# 3493  23851258502450009  AON IMAGEN_ABI_CPM_NA_BOLSA HOGAR - FACEBOOK_3...
# 3494  23851258502450009  AON IMAGEN_ABI_CPM_NA_BOLSA HOGAR - FACEBOOK_3...
# 3495  23851258502450009  AON IMAGEN_ABI_CPM_NA_BOLSA HOGAR - FACEBOOK_3...
#
#      ad_group_status    age  ... action_leadgen_other action_video_view  \
# 0             ACTIVE  18-24  ...                 <NA>                 0
# 1             ACTIVE  18-24  ...                 <NA>                 0
# 2             ACTIVE  25-34  ...                 <NA>                 0
# 3             ACTIVE  25-34  ...                 <NA>                 0
# 4             ACTIVE  35-44  ...                 <NA>                 0
# ...              ...    ...  ...                  ...               ...
# 3491          ACTIVE  45-54  ...                 <NA>                 0
# 3492          ACTIVE  45-54  ...                 <NA>                 0
# 3493          ACTIVE  55-64  ...                 <NA>                 0
# 3494          ACTIVE  55-64  ...                 <NA>                 0
# 3495          ACTIVE    65+  ...                 <NA>                 0
#
#      clicks    cost  cost_eur  cost_gbp  cost_usd  impressions  \
# 0       103  5.4698    5.4563    4.6898    5.4698         4872
# 1       107  5.1856    5.1728    4.4462    5.1856         5363
# 2       137  8.1082    8.0883    6.9520    8.1082         5222
# 3       142  9.5493    9.5257    8.1876    9.5493         7210
# 4        42  1.4207    1.4172    1.2181    1.4207          724
# ...     ...     ...       ...       ...       ...          ...
# 3491      1  0.0000    0.0000    0.0000    0.0000           44
# 3492      1  0.0000    0.0000    0.0000    0.0000           66
# 3493      1  0.0000    0.0000    0.0000    0.0000           55
# 3494      1  0.0000    0.0000    0.0000    0.0000           66
# 3495      1  0.0000    0.0000    0.0000    0.0000           22
#
#       onsite_conversion_lead_grouped  reach
# 0                                  0   3238
# 1                                  0   3327
# 2                                  0   3717
# 3                                  0   4735
# 4                                  0    568
# ...                              ...    ...
# 3491                               0     44
# 3492                               0     55
# 3493                               0     44
# 3494                               0     66
# 3495                               0     22
#
# [3496 rows x 24 columns]

# %%
client.query(


    
)
